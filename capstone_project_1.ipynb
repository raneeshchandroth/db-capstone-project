# %%
# !python3 --version
# Out:
# Python 3.14.1

# %%
# !pip3 install mysql-connector-python

# %%
import mysql.connector as connector

# %%
connection = connector.connect(user = "root", password = "MySqlConnection")

# %%
connection = connector.connect(user = "root", password = "MySqlConnection", db = "LittleLemonDB")

# %%
show_tables_query = "SHOW tables" 
cursor = connection.cursor()
cursor.execute(show_tables_query)
results = cursor.fetchall()

# %%
print(results)
# Out:
# [('Booking',), ('Customer_Details',), ('Menu',), ('MenuItems',), ('OrderDeliveryStatus',), ('Orders',), ('ordersview',), ('Staff_Information',)]

# %%
total_cost_by_customer_query = '''select * from Orders o join Customer_Details c on c.CustomerID = o.CustomerID
where o.TOtalCost > 60;'''
cursor.execute(total_cost_by_customer_query)
results = cursor.fetchall()
print(results)
# Out:
# [(4, 1, 3, 3, datetime.datetime(2026, 3, 15, 19, 15), 20, Decimal('240.00'), 1, 'Vanessa McCarthy', '555-0101', 'vanessa.m@example.com', '724 Parsley Lane, Old Town', 'Silver')]
